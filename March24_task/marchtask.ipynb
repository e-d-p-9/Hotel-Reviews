# %%
import pandas as pd

# %%
# read in both csvs
sub1 = pd.read_csv("Hotel_Sub_1.csv")
reviews = pd.read_csv("Hotel_Review_1000_selected_unlabeled.csv")

# %%
#display csvs
print("dataset that needs percentage")
print(sub1)
print("dataset that has full text")
print(reviews)
# Out:
# dataset that needs percentage
#       index                                               part  Annotations
# 0      8884  Excellent hotel in a great location. Close eno...            0
# 1      1098  Third time visit to this hotel. Rooms renovate...            1
# 2      4870  When we fly into Orlando to visit family on th...            1
# 3      6665  Close to airport but also close to a noisy roa...            1
# 4      7456  This is a great choice for Love Field area. Re...            1
# ...     ...                                                ...          ...
# 4995    994  Please avoid this hotel. After Hampton Inn los...            1
# 4996   5354         Cannot recommend this place enough. Great             1
# 4997   3532  Annual sibling reunion (3 siblings plus spouse...            1
# 4998   4915  Everyone, from Rebecca at check-in, Deborah at...            1
# 4999   6647  Ottimo hotel situato in buona posizione a met ...            1
#
# [5000 rows x 3 columns]
# dataset that has full text
#      Index reviews.ratings                                       reviews.text
# 0     4524        positive  Staff was exceptional, always a friendly smile...
# 1     7323        positive  We stayed here for a wedding. The staff was wo...
# 2     5070        positive  Very clean, pleasant facility. Environment of ...
# 3      266        positive  Everything was excellent will definitely be go...
# 4     9342        positive  Stayed here overnight in between flights throu...
# ..     ...             ...                                                ...
# 995   3032        negative  I am not a big fan of holiday inn but I came w...
# 996   3914        positive  nice place. friendly staff. i stayed in a delu...
# 997   4607        positive  We were in Webster for a wedding so we just st...
# 998     72        positive  Clean, spacious, and quiet rooms. Very comfort...
# 999   5555        positive  Moonstone Beach Motel is a great new building....
#
# [1000 rows x 3 columns]

# %%
# TODO
# add percentage of full column to sub1
# get id of row in sub1
# find id row in reviews
# compare character count between two
# use character count to quantify percentage of fullreview in reviews.csv
# populate percentage column  in sub1  with  correct percentage of  full
#  savesub1  with percentage  to csv  file
#  commit
#  send email

# %% [markdown]
# so iterate through subl
#
# get row at iteration
#
# grab id and text
# get character count of subl text
#
# find id in reviews
# get text in reviews by id
# get character count of text
#
# divide to get percentage
# round percentage to 20 40 60 80 100
#
# add the percentage to the current row in subl
#
# finish loop
#
# save csv of updated sub1 with percentage added

# %%
# create 2 row test data of sub1
testsub =sub1.head(2)

# %%
testsub
# Out:
#    index                                               part  Annotations
# 0   8884  Excellent hotel in a great location. Close eno...            0
# 1   1098  Third time visit to this hotel. Rooms renovate...            1

# %%
#list to hold percentages parallel to sub1 iteration
percent_list = []
for i in range(len(testsub)):
    # get current rows index
    current_index= testsub['index'].iloc[i]
    # get text count of part
    char_count = len(testsub['part'].iloc[i])
    # find row in reviews
    reviews_row = reviews[reviews['Index'] == current_index]
    # get character count of reviews text
    rev_char_count = len(reviews_row['reviews.text'].iloc[0])
    
    # divide to get percentage
    percentage = char_count / rev_char_count
    # add to list
    percent_list.append(percentage)
    
    print(f"character count: {char_count}")
    print(rev_char_count)
    print('------------------')
    


print(percent_list)

# add percentage column to sub1
testsub.insert(3, "Percent", percent_list, True)

testsub.to_csv("testpercentage.csv")
# Out:
# character count: 687
# 687
# ------------------
# character count: 200
# 501
# ------------------
# [1.0, 0.3992015968063872]

# %%
testsub
# Out:
#    index  ...   Percent
# 0   8884  ...  1.000000
# 1   1098  ...  0.399202
#
# [2 rows x 4 columns]

# %%
# list to hold percentages parallel to sub1 iteration
percent_list = []
for i in range(len(sub1)):
    # get current rows index
    current_index= sub1['index'].iloc[i]
    # get text count of part
    char_count = len(sub1['part'].iloc[i])
    # find row in reviews
    reviews_row = reviews[reviews['Index'] == current_index]
    # get character count of reviews text
    rev_char_count = len(reviews_row['reviews.text'].iloc[0])
    
    # divide to get percentage
    percentage = char_count / rev_char_count
    # add to list
    percent_list.append(percentage)

print(percent_list)
# add percentage column to sub1
sub1.insert(3, "Percent", percent_list, True)

sub1.to_csv("testpercentagesub1.csv")
# Out:
# [1.0, 0.3992015968063872, 0.199528672427337, 0.19985358711566617, 0.7982832618025751, 1.0, 1.0, 0.7980295566502463, 0.39959016393442626, 0.8, 0.19972404277337014, 0.3982494529540481, 1.0, 0.599437148217636, 1.0, 0.599388379204893, 0.5999155048584707, 0.7976878612716763, 1.0, 1.0, 0.39942938659058486, 0.5986394557823129, 0.1991701244813278, 1.0, 0.5966386554621849, 0.3984526112185687, 0.2, 0.1997929606625259, 0.3980263157894737, 0.799163179916318, 0.5995694294940797, 1.0, 0.7998251748251748, 0.5968379446640316, 0.7988165680473372, 0.5995316159250585, 0.5996600084997875, 0.5992578849721707, 0.8, 1.0, 1.0, 0.5959595959595959, 0.19943019943019943, 0.3993610223642173, 0.3976945244956772, 0.3968253968253968, 0.5989110707803993, 0.7984189723320159, 0.5996518711923412, 0.5977443609022557, 0.19910179640718562, 1.0, 0.39892665474060823, 0.4, 0.5992779783393501, 0.2, 1.0, 0.19972067039106145, 0.2, 0.7993527508090615, 0.5993589743589743, 1.0, 0.4, 0.6, 0.3997175141242938, 0.19834710743801653, 0.7995426829268293, 1.0, 0.2, 0.6, 0.7994428969359332, 1.0, 0.5994318181818182, 0.6, 0.5985037406483791, 0.6, 0.5993788819875776, 0.2, 1.0, 0.7991587802313355, 1.0, 0.6, 0.6, 0.5995623632385121, 0.3997445721583653, 1.0, 0.4, 0.2, 0.7989756722151088, 0.3983402489626556, 0.6, 0.39940387481371087, 1.0, 0.19935691318327975, 0.2, 0.5964912280701754, 0.4, 0.19678714859437751, 1.0, 0.6, 0.1984732824427481, 0.5991902834008097, 0.7982456140350878, 0.5990279465370595, 0.4, 0.7992351816443595, 0.4, 1.0, 0.19866071428571427, 1.0, 1.0, 0.39906103286384975, 1.0, 0.7989556135770235, 0.19696969696969696, 0.5992063492063492, 0.4, 0.7993920972644377, 0.8, 0.19902912621359223, 1.0, 0.8, 0.5996884735202492, 0.7995283018867925, 0.5982658959537572, 0.3964757709251101, 0.5977443609022557, 0.799405646359584, 0.5992578849721707, 0.8, 0.1990811638591118, 0.5991792065663475, 0.19805194805194806, 0.5983606557377049, 0.19856887298747763, 0.3981191222570533, 1.0, 0.19626168224299065, 0.5994344957587182, 0.7996031746031746, 0.8, 0.3979591836734694, 0.3975409836065574, 1.0, 0.7985865724381626, 0.19817073170731708, 0.1981981981981982, 1.0, 1.0, 0.5994865211810013, 0.7988980716253443, 0.39759036144578314, 0.7981651376146789, 0.8, 0.39853300733496333, 1.0, 0.19801980198019803, 0.797583081570997, 1.0, 0.5975609756097561, 0.5990990990990991, 1.0, 0.7995365005793743, 1.0, 0.2, 0.7987804878048781, 0.5998449011244669, 0.6, 0.39933993399339934, 0.799687825182102, 0.5980392156862745, 0.1984126984126984, 0.6, 0.2, 1.0, 1.0, 0.39939024390243905, 0.1997971602434077, 1.0, 0.19915254237288135, 0.39825581395348836, 0.19940029985007496, 0.8, 0.1998548270021776, 1.0, 0.5967078189300411, 0.5989010989010989, 0.19978969505783387, 0.7972027972027972, 0.3997233748271093, 0.7983193277310925, 0.5995762711864406, 1.0, 0.5994194484760522, 0.7993421052631579, 0.5991189427312775, 0.8, 1.0, 1.0, 0.1963470319634703, 0.599406528189911, 0.3984375, 0.3996050032916392, 1.0, 0.7991360691144709, 1.0, 0.3994413407821229, 0.5980392156862745, 1.0, 0.5997728133282847, 1.0, 0.6, 1.0, 1.0, 0.3999574286930609, 1.0, 0.2, 0.4, 0.19991438356164384, 0.5981308411214953, 0.7964601769911505, 1.0, 1.0, 0.2, 1.0, 1.0, 0.19904076738609114, 0.6, 0.398876404494382, 0.5997239475500346, 1.0, 0.19943622269203665, 0.1996124031007752, 0.6, 1.0, 0.5982905982905983, 0.2, 0.39886039886039887, 0.5997666277712952, 0.2, 1.0, 0.5979381443298969, 0.4, 0.3997599039615846, 0.2, 0.199438202247191, 0.799565453557849, 0.3994760969220694, 1.0, 0.19852941176470587, 0.3996383363471971, 1.0, 0.7997179125528914, 1.0, 0.2, 0.7971698113207547, 0.3990772779700115, 1.0, 0.5995203836930456, 0.1963470319634703, 0.6, 1.0, 0.3979591836734694, 1.0, 0.2, 0.3994823123382226, 0.4, 0.5983772819472617, 0.5993690851735016, 0.3992248062015504, 1.0, 0.39880952380952384, 0.7988826815642458, 0.39909297052154197, 0.1994572591587517, 0.1986754966887417, 0.39819004524886875, 1.0, 0.5997842502696872, 1.0, 0.5985401459854015, 1.0, 0.19958847736625515, 0.4, 0.1996996996996997, 0.1991 ...

# %%
sub1
# Out:
#       index  ...   Percent
# 0      8884  ...  1.000000
# 1      1098  ...  0.399202
# 2      4870  ...  0.199529
# 3      6665  ...  0.199854
# 4      7456  ...  0.798283
# ...     ...  ...       ...
# 4995    994  ...  1.000000
# 4996   5354  ...  0.200000
# 4997   3532  ...  0.400000
# 4998   4915  ...  0.799858
# 4999   6647  ...  0.399267
#
# [5000 rows x 4 columns]

# %%
percent_list
# Out:
# [1.0,
#  0.3992015968063872,
#  0.199528672427337,
#  0.19985358711566617,
#  0.7982832618025751,
#  1.0,
#  1.0,
#  0.7980295566502463,
#  0.39959016393442626,
#  0.8,
#  0.19972404277337014,
#  0.3982494529540481,
#  1.0,
#  0.599437148217636,
#  1.0,
#  0.599388379204893,
#  0.5999155048584707,
#  0.7976878612716763,
#  1.0,
#  1.0,
#  0.39942938659058486,
#  0.5986394557823129,
#  0.1991701244813278,
#  1.0,
#  0.5966386554621849,
#  0.3984526112185687,
#  0.2,
#  0.1997929606625259,
#  0.3980263157894737,
#  0.799163179916318,
#  0.5995694294940797,
#  1.0,
#  0.7998251748251748,
#  0.5968379446640316,
#  0.7988165680473372,
#  0.5995316159250585,
#  0.5996600084997875,
#  0.5992578849721707,
#  0.8,
#  1.0,
#  1.0,
#  0.5959595959595959,
#  0.19943019943019943,
#  0.3993610223642173,
#  0.3976945244956772,
#  0.3968253968253968,
#  0.5989110707803993,
#  0.7984189723320159,
#  0.5996518711923412,
#  0.5977443609022557,
#  0.19910179640718562,
#  1.0,
#  0.39892665474060823,
#  0.4,
#  0.5992779783393501,
#  0.2,
#  1.0,
#  0.19972067039106145,
#  0.2,
#  0.7993527508090615,
#  0.5993589743589743,
#  1.0,
#  0.4,
#  0.6,
#  0.3997175141242938,
#  0.19834710743801653,
#  0.7995426829268293,
#  1.0,
#  0.2,
#  0.6,
#  0.7994428969359332,
#  1.0,
#  0.5994318181818182,
#  0.6,
#  0.5985037406483791,
#  0.6,
#  0.5993788819875776,
#  0.2,
#  1.0,
#  0.7991587802313355,
#  1.0,
#  0.6,
#  0.6,
#  0.5995623632385121,
#  0.3997445721583653,
#  1.0,
#  0.4,
#  0.2,
#  0.7989756722151088,
#  0.3983402489626556,
#  0.6,
#  0.39940387481371087,
#  1.0,
#  0.19935691318327975,
#  0.2,
#  0.5964912280701754,
#  0.4,
#  0.19678714859437751,
#  1.0,
#  0.6,
#  0.1984732824427481,
#  0.5991902834008097,
#  0.7982456140350878,
#  0.5990279465370595,
#  0.4,
#  0.7992351816443595,
#  0.4,
#  1.0,
#  0.19866071428571427,
#  1.0,
#  1.0,
#  0.39906103286384975,
#  1.0,
#  0.7989556135770235,
#  0.19696969696969696,
#  0.5992063492063492,
#  0.4,
#  0.7993920972644377,
#  0.8,
#  0.19902912621359223,
#  1.0,
#  0.8,
#  0.5996884735202492,
#  0.7995283018867925,
#  0.5982658959537572,
#  0.3964757709251101,
#  0.5977443609022557,
#  0.799405646359584,
#  0.5992578849721707,
#  0.8,
#  0.1990811638591118,
#  0.5991792065663475,
#  0.19805194805194806,
#  0.5983606557377049,
#  0.19856887298747763,
#  0.3981191222570533,
#  1.0,
#  0.19626168224299065,
#  0.5994344957587182,
#  0.7996031746031746,
#  0.8,
#  0.3979591836734694,
#  0.3975409836065574,
#  1.0,
#  0.7985865724381626,
#  0.19817073170731708,
#  0.1981981981981982,
#  1.0,
#  1.0,
#  0.5994865211810013,
#  0.7988980716253443,
#  0.39759036144578314,
#  0.7981651376146789,
#  0.8,
#  0.39853300733496333,
#  1.0,
#  0.19801980198019803,
#  0.797583081570997,
#  1.0,
#  0.5975609756097561,
#  0.5990990990990991,
#  1.0,
#  0.7995365005793743,
#  1.0,
#  0.2,
#  0.7987804878048781,
#  0.5998449011244669,
#  0.6,
#  0.39933993399339934,
#  0.799687825182102,
#  0.5980392156862745,
#  0.1984126984126984,
#  0.6,
#  0.2,
#  1.0,
#  1.0,
#  0.39939024390243905,
#  0.1997971602434077,
#  1.0,
#  0.19915254237288135,
#  0.39825581395348836,
#  0.19940029985007496,
#  0.8,
#  0.1998548270021776,
#  1.0,
#  0.5967078189300411,
#  0.5989010989010989,
#  0.19978969505783387,
#  0.7972027972027972,
#  0.3997233748271093,
#  0.7983193277310925,
#  0.5995762711864406,
#  1.0,
#  0.5994194484760522,
#  0.7993421052631579,
#  0.5991189427312775,
#  0.8,
#  1.0,
#  1.0,
#  0.1963470319634703,
#  0.599406528189911,
#  0.3984375,
#  0.3996050032916392,
#  1.0,
#  0.7991360691144709,
#  1.0,
#  0.3994413407821229,
#  0.5980392156862745,
#  1.0,
#  0.5997728133282847,
#  1.0,
#  0.6,
#  1.0,
#  1.0,
#  0.3999574286930609,
#  1.0,
#  0.2,
#  0.4,
#  0.19991438356164384,
#  0.5981308411214953,
#  0.7964601769911505,
#  1.0,
#  1.0,
#  0.2,
#  1.0,
#  1.0,
#  0.19904076738609114,
#  0.6,
#  0.398876404494382,
#  0.5997239475500346,
#  1.0,
#  0.19943622269203665,
#  0.1996124031007752,
#  0.6,
#  1.0,
#  0.5982905982905983,
#  0.2,
#  0.39886039886039887,
#  0.5997666277712952,
#  0.2,
#  1.0,
#  0.5979381443298969,
#  0.4,
#  0.3997599039615846,
#  0.2,
#  0.199438202247191,
#  0.799565453557849,
#  0.3994760969220694,
#  1.0,
#  0.19852941176470587,
#  0.3996383363471971,
#  1.0,
#  0.7997179125528914,
#  1.0,
#  0.2,
#  0.7971698113207547,
#  0.3990772779700115,
#  1.0,
#  0.5995203836930456,
#  0.1963470319634703,
#  0.6,
#  1.0,
#  0.3979591836734694,
#  1.0,
#  0.2,
#  0.3994823123382226,
#  0.4,
#  0.5983772819472617,
#  0.5993690851735016,
#  0.3992248062015504,
#  1.0,
#  0.39880952380952384,
#  0.7988826815642458,
#  0.39909297052154197,
#  0.1994572591587517,
#  0.1986754966887417,
#  0.39819004524886875,
#  1.0,
#  0.5997842502696872,
#  1.0,
#  0.5985401459854015,
#  1.0,
#  0.19958847736625515,
#  0.4,
#  0.1996996996996997,
#  0.1991869918699187,
#  0.2,
#  0.3989983305509182,
#  0.39849624060150374,
#  0.7997138769670958,
#  0.5995611629182666,
#  1.0,
#  0.19753086419753085,
#  0.19831223628691982,
#  1.0,
#  0.5990396158463386,
#  0.5988538681948424,
#  0.39947780678851175,
#  0.3995943204868154,
#  0.39911797133406834,
#  0.4,
#  1.0,
#  0.3979591836734694,
#  0.19834710743801653,
#  0.39849624060150374,
#  0.5991332611050921,
#  0.5996131528046421,
#  0.3993610223642173,
#  0.8,
#  0.5987558320373251,
#  0.8,
#  0.2,
#  0.1993006993006993,
#  0.3987915407854985,
#  0.3997005988023952,
#  0.7982456140350878,
#  1.0,
#  0.8,
#  0.8,
#  0.797427652733119,
#  0.19817073170731708,
#  0.19921875,
#  0.2,
#  0.2,
#  0.2,
#  1.0,
#  0.4,
#  0.79890560875513,
#  0.7983193277310925,
#  0.7976190476190477,
#  0.19984945427173503,
#  0.7976653696498055,
#  1.0,
#  0.19986675549633579,
#  0.7991803278688525,
#  1.0,
#  0.6,
#  0.1999170468685193,
#  0.6,
#  0.19940476190476192,
#  1.0,
#  0.3972602739726027,
#  0.3991031390134529,
#  1.0,
#  0.8,
#  0.39925373134328357,
#  0.596958174904943,
#  0.19727891156462585,
#  0.19742489270386265,
#  0.39935064935064934,
#  0.7977099236641222,
#  0.6,
#  0.1998310097169413,
#  0.6,
#  0.8,
#  0.7989276139410187,
#  0.7976653696498055,
#  0.5995260663507109,
#  0.19961427193828352,
#  0.6,
#  0.2,
#  0.7990762124711316,
#  1.0,
#  0.8,
#  0.5995934959349594,
#  0.7986577181208053,
#  1.0,
#  0.39882697947214074,
#  0.19959541469993258,
#  0.5997366688610928,
#  0.7994891443167306,
#  0.4,
#  0.598705501618123,
#  0.19811320754716982,
#  0.799410029498525,
#  0.8,
#  0.5994005994005994,
#  0.39805825242718446,
#  0.7990654205607477,
#  0.8,
#  0.1994991652754591,
#  0.3993610223642173,
#  0.2,
#  1.0,
#  0.7994652406417112,
#  0.8,
#  0.5995623632385121,
#  0.7990430622009569,
#  0.8,
#  0.7984293193717278,
#  0.6,
#  0.7998619737750172,
#  0.1986062717770035,
#  0.5971563981042654,
#  0.3996815286624204,
#  0.19964028776978418,
#  0.19924812030075187,
#  0.5964912280701754,
#  0.7971014492753623,
#  1.0,
#  1.0,
#  0.19831223628691982,
#  0.5993322203672788,
#  1.0,
#  0.4,
#  0.799800796812749,
#  0.5971223021582733,
#  0.39968774395003903,
#  0.19973009446693657,
#  1.0,
#  0.7990353697749196,
#  0.4,
#  0.19791666666666666,
#  0.8,
#  1.0,
#  0.1986455981941309,
#  0.5993589743589743,
#  0.3987341772151899,
#  1.0,
#  1.0,
#  0.19917440660474717,
#  0.3972602739726027,
#  0.799163179916318,
#  0.5995449374288965,
#  0.5975103734439834,
#  0.19939577039274925,
#  0.2,
#  0.3983050847457627,
#  0.19742489270386265,
#  0.19873150105708245,
#  1.0,
#  0.3985239852398524,
#  1.0,
#  0.5993589743589743,
#  0.5998256320836965,
#  0.7982456140350878,
#  1.0,
#  0.3993260320134794,
#  1.0,
#  0.19942816297355254,
#  0.5982142857142857,
#  0.3993231810490694,
#  0.3988995873452545,
#  0.7994768962510898,
#  0.19900497512437812,
#  0.5997239475500346,
#  0.5992063492063492,
#  0.3975409836065574,
#  0.1994750656167979,
#  0.19736842105263158,
#  1.0,
#  0.7981366459627329,
#  0.5973597359735974,
#  0.19949174078780177,
#  0.3987538940809969,
#  1.0,
#  0.5985790408525755,
#  1.0,
#  0.19933554817275748,
#  0.2,
#  0.2,
#  0.5990990990990991,
#  0.2,
#  0.8,
#  0.8,
#  0.7969924812030075,
#  0.19784172661870503,
#  0.399452804377565,
#  0.4,
#  0.19742489270386265,
#  0.3986820428336079,
#  0.5993690851735016,
#  1.0,
#  0.19904458598726116,
#  1.0,
#  0.5993788819875776,
#  0.39914163090128757,
#  0.5997349237905898,
#  0.5987654320987654,
#  0.2,
#  0.6,
#  1.0,
#  0.19964028776978418,
#  0.5985401459854015,
#  1.0,
#  0.19933554817275748,
#  0.19736842105263158,
#  0.6,
#  0.5984455958549223,
#  0.3980891719745223,
#  0.19927095990279464,
#  1.0,
#  1.0,
#  0.1989342806394316,
#  0.6,
#  0.8,
#  1.0,
#  1.0,
#  0.19727891156462585,
#  0.5998071359691417,
#  0.6,
#  0.6,
#  1.0,
#  0.3996865203761755,
#  1.0,
#  0.8,
#  0.8,
#  1.0,
#  0.4,
#  0.39473684210526316,
#  0.2,
#  0.3999181334424887,
#  0.8,
#  0.39900249376558605,
#  0.7985611510791367,
#  0.4,
#  0.3996975806451613,
#  0.3995880535530381,
#  1.0,
#  0.5998064360029035,
#  0.19979188345473464,
#  0.7990654205607477,
#  0.7987804878048781,
#  0.19907407407407407,
#  0.1995827538247566,
#  0.39902676399026765,
#  1.0,
#  0.6,
#  1.0,
#  0.8,
#  0.7982832618025751,
#  1.0,
#  0.7986425339366516,
#  1.0,
#  0.7994428969359332,
#  0.5997109826589595,
#  1.0,
#  0.19838056680161945,
#  0.4,
#  0.6,
#  0.5994436717663422,
#  0.5998389694041868,
#  1.0,
#  0.8,
#  0.5967078189300411,
#  1.0,
#  1.0,
#  0.3994140625,
#  1.0,
#  0.19959677419354838,
#  0.5995085995085995,
#  0.7972972972972973,
#  0.19935691318327975,
#  0.8,
#  0.19851576994434136,
#  1.0,
#  0.4,
#  1.0,
#  0.1977077363896848,
#  0.7982261640798226,
#  0.5985663082437276,
#  0.3973509933774834,
#  0.5982905982905983,
#  1.0,
#  0.5992779783393501,
#  0.6,
#  0.5991091314031181,
#  0.6,
#  0.7992998833138857,
#  0.5996797437950361,
#  0.6,
#  0.2,
#  0.5974842767295597,
#  0.5996343692870201,
#  0.7991266375545851,
#  0.2,
#  1.0,
#  0.1968503937007874,
#  0.19979188345473464,
#  0.6,
#  0.4,
#  0.19955156950672645,
#  1.0,
#  0.2,
#  0.5992366412213741,
#  0.3993993993993994,
#  0.5996932515337423,
#  0.5994152046783626,
#  1.0,
#  0.19941348973607037,
#  1.0,
#  0.8,
#  0.8,
#  0.5993294216261525,
#  0.3970037453183521,
#  1.0,
#  0.39913700107874867,
#  0.4,
#  1.0,
#  0.19968304278922344,
#  0.8,
#  0.4,
#  1.0,
#  0.399702823179792,
#  0.7989778534923339,
#  1.0,
#  0.8,
#  1.0,
#  1.0,
#  0.19948186528497408,
#  0.5980707395498392,
#  1.0,
#  0.7996987951807228,
#  0.39747634069400634,
#  0.7982456140350878,
#  0.6,
#  0.5965665236051502,
#  0.39939024390243905,
#  1.0,
#  1.0,
#  0.6,
#  0.7998331943286072,
#  0.5993265993265994,
#  0.1976284584980237,
#  0.5972696245733788,
#  0.6,
#  0.7993630573248408,
#  0.5991943605236657,
#  0.5980066445182725,
#  0.39937106918238996,
#  0.7977941176470589,
#  0.3980891719745223,
#  0.5982905982905983,
#  0.19967266775777415,
#  0.5983606557377049,
#  0.5993589743589743,
#  0.6,
#  1.0,
#  0.39932885906040266,
#  0.39800995024875624,
#  0.5988372093023255,
#  0.4,
#  0.39960629921259844,
#  0.7987804878048781,
#  0.7996688741721855,
#  0.7994011976047904,
#  0.5984555984555985,
#  0.4,
#  0.6,
#  0.19617224880382775,
#  0.4,
#  0.7997335701598579,
#  0.8,
#  0.5990037359900373,
#  1.0,
#  0.19736842105263158,
#  0.397212543554007,
#  0.7996485061511424,
#  1.0,
#  0.7980132450331126,
#  0.7985611510791367,
#  0.599640933572711,
#  0.39886039886039887,
#  0.1994535519125683,
#  0.3976945244956772,
#  0.39920948616600793,
#  0.6,
#  1.0,
#  0.5993520518358532,
#  0.6,
#  0.1998792270531401,
#  0.19745222929936307,
#  0.7979094076655052,
#  0.19924812030075187,
#  0.6,
#  0.39935064935064934,
#  0.7970297029702971,
#  0.5984555984555985,
#  1.0,
#  1.0,
#  0.7992007992007992,
#  0.3980891719745223,
#  1.0,
#  0.3994360902255639,
#  0.19843342036553524,
#  0.4,
#  1.0,
#  0.1970260223048327,
#  0.5991379310344828,
#  0.7982062780269058,
#  0.3988549618320611,
#  0.2,
#  0.7980769230769231,
#  1.0,
#  1.0,
#  0.7994505494505495,
#  0.39914163090128757,
#  0.5979020979020979,
#  0.19964664310954064,
#  0.7994467496542186,
#  0.39800995024875624,
#  0.7998345740281224,
#  0.39927184466019416,
#  0.2,
#  0.5988700564971752,
#  0.1994645247657296,
#  1.0,
#  0.7993630573248408,
#  0.7962085308056872,
#  1.0,
#  1.0,
#  0.4,
#  0.5990510083036773,
#  0.2,
#  1.0,
#  0.19730941704035873,
#  0.7981651376146789,
#  0.39902676399026765,
#  1.0,
#  1.0,
#  0.5990159901599016,
#  0.19910846953937592,
#  0.6,
#  0.5988023952095808,
#  0.797752808988764,
#  0.7993527508090615,
#  0.4,
#  0.7974137931034483,
#  0.7986906710310966,
#  0.39823008849557523,
#  0.7987321711568938,
#  1.0,
#  0.8,
#  1.0,
#  0.3998790078644888,
#  0.7982062780269058,
#  1.0,
#  0.1989795918367347,
#  0.5998307952622673,
#  0.5980066445182725,
#  0.19742489270386265,
#  1.0,
#  0.7992202729044834,
#  0.3969465648854962,
#  1.0,
#  0.6,
#  1.0,
#  0.39976825028968715,
#  1.0,
#  0.6,
#  0.19982238010657194,
#  0.1987179487179487,
#  0.8,
#  0.3971631205673759,
#  0.6,
#  0.39805825242718446,
#  0.39920948616600793,
#  0.2,
#  0.6,
#  1.0,
#  0.1997792494481236,
#  0.39976415094339623,
#  0.2,
#  1.0,
#  0.3995726495726496,
#  0.7973568281938326,
#  0.3995726495726496,
#  0.8,
#  0.6,
#  0.3991655076495132,
#  0.797979797979798,
#  0.1998262380538662,
#  0.6,
#  0.4,
#  1.0,
#  0.4,
#  0.39944903581267216,
#  0.2,
#  0.2,
#  1.0,
#  0.3993558776167472,
#  1.0,
#  0.5996758508914101,
#  1.0,
#  1.0,
#  0.5975609756097561,
#  0.7992277992277992,
#  1.0,
#  1.0,
#  0.8,
#  0.5982142857142857,
#  0.3969465648854962,
#  0.6,
#  0.7985347985347986,
#  0.7982062780269058,
#  0.7989130434782609,
#  0.7980535279805353,
#  1.0,
#  0.8,
#  1.0,
#  0.4,
#  0.5989717223650386,
#  0.4,
#  1.0,
#  0.7977941176470589,
#  0.7999224505622334,
#  0.5993485342019544,
#  1.0,
#  0.1993517017828201,
#  1.0,
#  0.5973154362416108,
#  0.5964125560538116,
#  0.7991803278688525,
#  0.7994987468671679,
#  0.6,
#  0.6,
#  0.19973190348525469,
#  0.7991452991452992,
#  0.1974921630094044,
#  0.6,
#  1.0,
#  0.3999105345560277,
#  0.7993754879000781,
#  0.3998242530755712,
#  0.5968379446640316,
#  0.39872068230277186,
#  0.7986577181208053,
#  0.1971326164874552,
#  0.5961538461538461,
#  0.5998197386210005,
#  1.0,
#  0.39952153110047844,
#  1.0,
#  0.8,
#  0.399624765478424,
#  0.7996331957817515,
#  0.19921875,
#  0.1995841995841996,
#  0.7969924812030075,
#  1.0,
#  0.7998955067920586,
#  0.3979591836734694,
#  0.2,
#  0.19909502262443438,
#  0.7973856209150327,
#  1.0,
#  0.19927536231884058,
#  0.7998204667863554,
#  0.4,
#  0.39970171513795677,
#  0.4,
#  0.5983935742971888,
#  0.5987525987525988,
#  1.0,
#  0.5991902834008097,
#  0.39964943032427697,
#  0.7977207977207977,
#  0.3986013986013986,
#  0.6,
#  0.7998590556730092,
#  0.199642431466031,
#  0.2,
#  0.3996683250414594,
#  0.7972972972972973,
#  0.3993660855784469,
#  0.3974358974358974,
#  0.19877675840978593,
#  0.7992277992277992,
#  0.4,
#  1.0,
#  0.4,
#  0.1987704918032787,
#  0.8,
#  0.799839871897518,
#  0.7983539094650206,
#  0.3997214484679666,
#  0.5984251968503937,
#  0.3991228070175439,
#  0.599644128113879,
#  0.19963369963369965,
#  0.2,
#  0.19935691318327975,
#  1.0,
#  0.3988439306358382,
#  0.2,
#  0.39705882352941174,
#  0.5994436717663422,
#  0.5998164295548417,
#  0.39921722113502933,
#  0.5963302752293578,
#  0.39901477832512317,
#  1.0,
#  0.4,
#  0.19961612284069097,
#  0.5980707395498392,
#  1.0,
#  0.199252801992528,
#  0.4,
#  0.8,
#  0.7994505494505495,
#  0.3981762917933131,
#  0.19924098671726756,
#  0.5987124463519313,
#  0.3995502248875562,
#  0.4,
#  0.5981308411214953,
#  1.0,
#  1.0,
#  1.0,
#  0.6,
#  0.19934640522875818,
#  1.0,
#  1.0,
#  0.5994550408719346,
#  0.7978723404255319,
#  0.5990491283676703,
#  0.1992619926199262,
#  0.4,
#  1.0,
#  0.39937106918238996,
#  0.2,
#  0.1976284584980237,
#  0.7991967871485943,
#  0.8,
#  0.1978798586572438,
#  1.0,
#  1.0,
#  0.8,
#  0.398989898989899,
#  0.19975859987929995,
#  0.7987012987012987,
#  0.8,
#  0.19843342036553524,
#  0.6,
#  1.0,
#  0.8,
#  0.5991561181434599,
#  0.19969278033794163,
#  0.39755351681957185,
#  0.7981651376146789,
#  0.2,
#  0.1996871741397289,
#  0.19944341372912802,
#  0.19974874371859297,
#  0.7997208653175157,
#  0.19975786924939468,
#  0.7994858611825193,
#  1.0,
#  1.0,
#  0.5990990990990991,
#  0.5998062015503876,
#  0.2,
#  0.19915254237288135,
#  1.0,
#  0.19665271966527198,
#  0.1956521739130435,
#  0.1987179487179487,
#  1.0,
#  0.39755351681957185,
#  0.7993366500829188,
#  0.7972972972972973,
#  0.39867109634551495,
#  0.1978021978021978,
#  0.6,
#  1.0,
#  0.5971563981042654,
#  0.5993975903614458,
#  0.39959839357429716,
#  0.5981735159817352,
#  0.5993377483443708,
#  1.0,
#  0.2,
#  0.2,
#  0.39898348157560354,
#  0.7971014492753623,
#  0.4,
#  1.0,
#  0.5996835443037974,
#  0.7982062780269058,
#  0.7995255041518387,
#  0.5987261146496815,
#  0.6,
#  0.19821826280623608,
#  0.4,
#  0.5997566909975669,
#  0.5996621621621622,
#  0.4,
#  0.599879481771618,
#  1.0,
#  1.0,
#  0.1996370235934664,
#  0.5976095617529881,
#  0.1997471554993679,
#  0.4,
#  0.2,
#  0.5981308411214953,
#  0.8,
#  0.7982708933717579,
#  0.3995837669094693,
#  0.5978835978835979,
#  ...]

# %%
import numpy as np

# %%
rounded = np.ceil(percent_list * 100)

# %%
test = [percent_list[i] * 100 for i in range(len(percent_list))]
test = [int(np.ceil(test[i])) for i in range(len(test))]
test
# Out:
# [100,
#  40,
#  20,
#  20,
#  80,
#  100,
#  100,
#  80,
#  40,
#  80,
#  20,
#  40,
#  100,
#  60,
#  100,
#  60,
#  60,
#  80,
#  100,
#  100,
#  40,
#  60,
#  20,
#  100,
#  60,
#  40,
#  20,
#  20,
#  40,
#  80,
#  60,
#  100,
#  80,
#  60,
#  80,
#  60,
#  60,
#  60,
#  80,
#  100,
#  100,
#  60,
#  20,
#  40,
#  40,
#  40,
#  60,
#  80,
#  60,
#  60,
#  20,
#  100,
#  40,
#  40,
#  60,
#  20,
#  100,
#  20,
#  20,
#  80,
#  60,
#  100,
#  40,
#  60,
#  40,
#  20,
#  80,
#  100,
#  20,
#  60,
#  80,
#  100,
#  60,
#  60,
#  60,
#  60,
#  60,
#  20,
#  100,
#  80,
#  100,
#  60,
#  60,
#  60,
#  40,
#  100,
#  40,
#  20,
#  80,
#  40,
#  60,
#  40,
#  100,
#  20,
#  20,
#  60,
#  40,
#  20,
#  100,
#  60,
#  20,
#  60,
#  80,
#  60,
#  40,
#  80,
#  40,
#  100,
#  20,
#  100,
#  100,
#  40,
#  100,
#  80,
#  20,
#  60,
#  40,
#  80,
#  80,
#  20,
#  100,
#  80,
#  60,
#  80,
#  60,
#  40,
#  60,
#  80,
#  60,
#  80,
#  20,
#  60,
#  20,
#  60,
#  20,
#  40,
#  100,
#  20,
#  60,
#  80,
#  80,
#  40,
#  40,
#  100,
#  80,
#  20,
#  20,
#  100,
#  100,
#  60,
#  80,
#  40,
#  80,
#  80,
#  40,
#  100,
#  20,
#  80,
#  100,
#  60,
#  60,
#  100,
#  80,
#  100,
#  20,
#  80,
#  60,
#  60,
#  40,
#  80,
#  60,
#  20,
#  60,
#  20,
#  100,
#  100,
#  40,
#  20,
#  100,
#  20,
#  40,
#  20,
#  80,
#  20,
#  100,
#  60,
#  60,
#  20,
#  80,
#  40,
#  80,
#  60,
#  100,
#  60,
#  80,
#  60,
#  80,
#  100,
#  100,
#  20,
#  60,
#  40,
#  40,
#  100,
#  80,
#  100,
#  40,
#  60,
#  100,
#  60,
#  100,
#  60,
#  100,
#  100,
#  40,
#  100,
#  20,
#  40,
#  20,
#  60,
#  80,
#  100,
#  100,
#  20,
#  100,
#  100,
#  20,
#  60,
#  40,
#  60,
#  100,
#  20,
#  20,
#  60,
#  100,
#  60,
#  20,
#  40,
#  60,
#  20,
#  100,
#  60,
#  40,
#  40,
#  20,
#  20,
#  80,
#  40,
#  100,
#  20,
#  40,
#  100,
#  80,
#  100,
#  20,
#  80,
#  40,
#  100,
#  60,
#  20,
#  60,
#  100,
#  40,
#  100,
#  20,
#  40,
#  40,
#  60,
#  60,
#  40,
#  100,
#  40,
#  80,
#  40,
#  20,
#  20,
#  40,
#  100,
#  60,
#  100,
#  60,
#  100,
#  20,
#  40,
#  20,
#  20,
#  20,
#  40,
#  40,
#  80,
#  60,
#  100,
#  20,
#  20,
#  100,
#  60,
#  60,
#  40,
#  40,
#  40,
#  40,
#  100,
#  40,
#  20,
#  40,
#  60,
#  60,
#  40,
#  80,
#  60,
#  80,
#  20,
#  20,
#  40,
#  40,
#  80,
#  100,
#  80,
#  80,
#  80,
#  20,
#  20,
#  20,
#  20,
#  20,
#  100,
#  40,
#  80,
#  80,
#  80,
#  20,
#  80,
#  100,
#  20,
#  80,
#  100,
#  60,
#  20,
#  60,
#  20,
#  100,
#  40,
#  40,
#  100,
#  80,
#  40,
#  60,
#  20,
#  20,
#  40,
#  80,
#  60,
#  20,
#  60,
#  80,
#  80,
#  80,
#  60,
#  20,
#  60,
#  20,
#  80,
#  100,
#  80,
#  60,
#  80,
#  100,
#  40,
#  20,
#  60,
#  80,
#  40,
#  60,
#  20,
#  80,
#  80,
#  60,
#  40,
#  80,
#  80,
#  20,
#  40,
#  20,
#  100,
#  80,
#  80,
#  60,
#  80,
#  80,
#  80,
#  60,
#  80,
#  20,
#  60,
#  40,
#  20,
#  20,
#  60,
#  80,
#  100,
#  100,
#  20,
#  60,
#  100,
#  40,
#  80,
#  60,
#  40,
#  20,
#  100,
#  80,
#  40,
#  20,
#  80,
#  100,
#  20,
#  60,
#  40,
#  100,
#  100,
#  20,
#  40,
#  80,
#  60,
#  60,
#  20,
#  20,
#  40,
#  20,
#  20,
#  100,
#  40,
#  100,
#  60,
#  60,
#  80,
#  100,
#  40,
#  100,
#  20,
#  60,
#  40,
#  40,
#  80,
#  20,
#  60,
#  60,
#  40,
#  20,
#  20,
#  100,
#  80,
#  60,
#  20,
#  40,
#  100,
#  60,
#  100,
#  20,
#  20,
#  20,
#  60,
#  20,
#  80,
#  80,
#  80,
#  20,
#  40,
#  40,
#  20,
#  40,
#  60,
#  100,
#  20,
#  100,
#  60,
#  40,
#  60,
#  60,
#  20,
#  60,
#  100,
#  20,
#  60,
#  100,
#  20,
#  20,
#  60,
#  60,
#  40,
#  20,
#  100,
#  100,
#  20,
#  60,
#  80,
#  100,
#  100,
#  20,
#  60,
#  60,
#  60,
#  100,
#  40,
#  100,
#  80,
#  80,
#  100,
#  40,
#  40,
#  20,
#  40,
#  80,
#  40,
#  80,
#  40,
#  40,
#  40,
#  100,
#  60,
#  20,
#  80,
#  80,
#  20,
#  20,
#  40,
#  100,
#  60,
#  100,
#  80,
#  80,
#  100,
#  80,
#  100,
#  80,
#  60,
#  100,
#  20,
#  40,
#  60,
#  60,
#  60,
#  100,
#  80,
#  60,
#  100,
#  100,
#  40,
#  100,
#  20,
#  60,
#  80,
#  20,
#  80,
#  20,
#  100,
#  40,
#  100,
#  20,
#  80,
#  60,
#  40,
#  60,
#  100,
#  60,
#  60,
#  60,
#  60,
#  80,
#  60,
#  60,
#  20,
#  60,
#  60,
#  80,
#  20,
#  100,
#  20,
#  20,
#  60,
#  40,
#  20,
#  100,
#  20,
#  60,
#  40,
#  60,
#  60,
#  100,
#  20,
#  100,
#  80,
#  80,
#  60,
#  40,
#  100,
#  40,
#  40,
#  100,
#  20,
#  80,
#  40,
#  100,
#  40,
#  80,
#  100,
#  80,
#  100,
#  100,
#  20,
#  60,
#  100,
#  80,
#  40,
#  80,
#  60,
#  60,
#  40,
#  100,
#  100,
#  60,
#  80,
#  60,
#  20,
#  60,
#  60,
#  80,
#  60,
#  60,
#  40,
#  80,
#  40,
#  60,
#  20,
#  60,
#  60,
#  60,
#  100,
#  40,
#  40,
#  60,
#  40,
#  40,
#  80,
#  80,
#  80,
#  60,
#  40,
#  60,
#  20,
#  40,
#  80,
#  80,
#  60,
#  100,
#  20,
#  40,
#  80,
#  100,
#  80,
#  80,
#  60,
#  40,
#  20,
#  40,
#  40,
#  60,
#  100,
#  60,
#  60,
#  20,
#  20,
#  80,
#  20,
#  60,
#  40,
#  80,
#  60,
#  100,
#  100,
#  80,
#  40,
#  100,
#  40,
#  20,
#  40,
#  100,
#  20,
#  60,
#  80,
#  40,
#  20,
#  80,
#  100,
#  100,
#  80,
#  40,
#  60,
#  20,
#  80,
#  40,
#  80,
#  40,
#  20,
#  60,
#  20,
#  100,
#  80,
#  80,
#  100,
#  100,
#  40,
#  60,
#  20,
#  100,
#  20,
#  80,
#  40,
#  100,
#  100,
#  60,
#  20,
#  60,
#  60,
#  80,
#  80,
#  40,
#  80,
#  80,
#  40,
#  80,
#  100,
#  80,
#  100,
#  40,
#  80,
#  100,
#  20,
#  60,
#  60,
#  20,
#  100,
#  80,
#  40,
#  100,
#  60,
#  100,
#  40,
#  100,
#  60,
#  20,
#  20,
#  80,
#  40,
#  60,
#  40,
#  40,
#  20,
#  60,
#  100,
#  20,
#  40,
#  20,
#  100,
#  40,
#  80,
#  40,
#  80,
#  60,
#  40,
#  80,
#  20,
#  60,
#  40,
#  100,
#  40,
#  40,
#  20,
#  20,
#  100,
#  40,
#  100,
#  60,
#  100,
#  100,
#  60,
#  80,
#  100,
#  100,
#  80,
#  60,
#  40,
#  60,
#  80,
#  80,
#  80,
#  80,
#  100,
#  80,
#  100,
#  40,
#  60,
#  40,
#  100,
#  80,
#  80,
#  60,
#  100,
#  20,
#  100,
#  60,
#  60,
#  80,
#  80,
#  60,
#  60,
#  20,
#  80,
#  20,
#  60,
#  100,
#  40,
#  80,
#  40,
#  60,
#  40,
#  80,
#  20,
#  60,
#  60,
#  100,
#  40,
#  100,
#  80,
#  40,
#  80,
#  20,
#  20,
#  80,
#  100,
#  80,
#  40,
#  20,
#  20,
#  80,
#  100,
#  20,
#  80,
#  40,
#  40,
#  40,
#  60,
#  60,
#  100,
#  60,
#  40,
#  80,
#  40,
#  60,
#  80,
#  20,
#  20,
#  40,
#  80,
#  40,
#  40,
#  20,
#  80,
#  40,
#  100,
#  40,
#  20,
#  80,
#  80,
#  80,
#  40,
#  60,
#  40,
#  60,
#  20,
#  20,
#  20,
#  100,
#  40,
#  20,
#  40,
#  60,
#  60,
#  40,
#  60,
#  40,
#  100,
#  40,
#  20,
#  60,
#  100,
#  20,
#  40,
#  80,
#  80,
#  40,
#  20,
#  60,
#  40,
#  40,
#  60,
#  100,
#  100,
#  100,
#  60,
#  20,
#  100,
#  100,
#  60,
#  80,
#  60,
#  20,
#  40,
#  100,
#  40,
#  20,
#  20,
#  80,
#  80,
#  20,
#  100,
#  100,
#  80,
#  40,
#  20,
#  80,
#  80,
#  20,
#  60,
#  100,
#  80,
#  60,
#  20,
#  40,
#  80,
#  20,
#  20,
#  20,
#  20,
#  80,
#  20,
#  80,
#  100,
#  100,
#  60,
#  60,
#  20,
#  20,
#  100,
#  20,
#  20,
#  20,
#  100,
#  40,
#  80,
#  80,
#  40,
#  20,
#  60,
#  100,
#  60,
#  60,
#  40,
#  60,
#  60,
#  100,
#  20,
#  20,
#  40,
#  80,
#  40,
#  100,
#  60,
#  80,
#  80,
#  60,
#  60,
#  20,
#  40,
#  60,
#  60,
#  40,
#  60,
#  100,
#  100,
#  20,
#  60,
#  20,
#  40,
#  20,
#  60,
#  80,
#  80,
#  40,
#  60,
#  ...]

# %%
import pandas as pd

# %%
# read in both csvs
sub1 = pd.read_csv("Hotel_Sub_1.csv", index_col=0)
reviews = pd.read_csv("Hotel_Review_1000_selected_unlabeled.csv", index_col=0)

# %%
#display csvs
sub1
# Out:
#                                                     part  Annotations
# index
# 8884   Excellent hotel in a great location. Close eno...            0
# 1098   Third time visit to this hotel. Rooms renovate...            1
# 4870   When we fly into Orlando to visit family on th...            1
# 6665   Close to airport but also close to a noisy roa...            1
# 7456   This is a great choice for Love Field area. Re...            1
# ...                                                  ...          ...
# 994    Please avoid this hotel. After Hampton Inn los...            1
# 5354          Cannot recommend this place enough. Great             1
# 3532   Annual sibling reunion (3 siblings plus spouse...            1
# 4915   Everyone, from Rebecca at check-in, Deborah at...            1
# 6647   Ottimo hotel situato in buona posizione a met ...            1
#
# [5000 rows x 2 columns]

# %%
reviews
# Out:
#       reviews.ratings                                       reviews.text
# Index
# 4524         positive  Staff was exceptional, always a friendly smile...
# 7323         positive  We stayed here for a wedding. The staff was wo...
# 5070         positive  Very clean, pleasant facility. Environment of ...
# 266          positive  Everything was excellent will definitely be go...
# 9342         positive  Stayed here overnight in between flights throu...
# ...               ...                                                ...
# 3032         negative  I am not a big fan of holiday inn but I came w...
# 3914         positive  nice place. friendly staff. i stayed in a delu...
# 4607         positive  We were in Webster for a wedding so we just st...
# 72           positive  Clean, spacious, and quiet rooms. Very comfort...
# 5555         positive  Moonstone Beach Motel is a great new building....
#
# [1000 rows x 2 columns]

# %%
# TODO
# add percentage of full column to sub1
# get id of row in sub1
# find id row in reviews
# compare character count between two
# use character count to quantify percentage of fullreview in reviews.csv
# populate percentage column  in sub1  with  correct percentage of  full
#  savesub1  with percentage  to csv  file
#  commit
#  send email

# %%
sub1.loc["Index"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-b5051fa031dc> in <module>
# ----> 1 sub1.loc["Index"]
#
# ~/lib/python3.10/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
# ...

# %%
dir(sub1.iloc[0])
# Out:
# ['Annotations',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
# ...

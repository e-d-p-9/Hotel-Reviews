# %%
import pandas as pd

# %%
# read in both csvs
sub1 = pd.read_csv("Hotel_Sub_1.csv")
reviews = pd.read_csv("Hotel_Review_1000_selected_unlabeled.csv")

# %%
#display csvs
print("dataset that needs percentage")
print(sub1)
print("dataset that has full text")
print(reviews)
# Out:
# dataset that needs percentage
#       index                                               part  Annotations
# 0      8884  Excellent hotel in a great location. Close eno...            0
# 1      1098  Third time visit to this hotel. Rooms renovate...            1
# 2      4870  When we fly into Orlando to visit family on th...            1
# 3      6665  Close to airport but also close to a noisy roa...            1
# 4      7456  This is a great choice for Love Field area. Re...            1
# ...     ...                                                ...          ...
# 4995    994  Please avoid this hotel. After Hampton Inn los...            1
# 4996   5354         Cannot recommend this place enough. Great             1
# 4997   3532  Annual sibling reunion (3 siblings plus spouse...            1
# 4998   4915  Everyone, from Rebecca at check-in, Deborah at...            1
# 4999   6647  Ottimo hotel situato in buona posizione a met ...            1
#
# [5000 rows x 3 columns]
# dataset that has full text
#      Index reviews.ratings                                       reviews.text
# 0     4524        positive  Staff was exceptional, always a friendly smile...
# 1     7323        positive  We stayed here for a wedding. The staff was wo...
# 2     5070        positive  Very clean, pleasant facility. Environment of ...
# 3      266        positive  Everything was excellent will definitely be go...
# 4     9342        positive  Stayed here overnight in between flights throu...
# ..     ...             ...                                                ...
# 995   3032        negative  I am not a big fan of holiday inn but I came w...
# 996   3914        positive  nice place. friendly staff. i stayed in a delu...
# 997   4607        positive  We were in Webster for a wedding so we just st...
# 998     72        positive  Clean, spacious, and quiet rooms. Very comfort...
# 999   5555        positive  Moonstone Beach Motel is a great new building....
#
# [1000 rows x 3 columns]

# %%
# TODO
# add percentage of full column to sub1
# get id of row in sub1
# find id row in reviews
# compare character count between two
# use character count to quantify percentage of fullreview in reviews.csv
# populate percentage column  in sub1  with  correct percentage of  full
#  savesub1  with percentage  to csv  file
#  commit
#  send email

# %% [markdown]
# so iterate through subl
#
# get row at iteration
#
# grab id and text
# get character count of subl text
#
# find id in reviews
# get text in reviews by id
# get character count of text
#
# divide to get percentage
# round percentage to 20 40 60 80 100
#
# add the percentage to the current row in subl
#
# finish loop
#
# save csv of updated sub1 with percentage added

# %%
# create 2 row test data of sub1
testsub =sub1.head(2)

# %%
testsub
# Out:
#    index                                               part  Annotations
# 0   8884  Excellent hotel in a great location. Close eno...            0
# 1   1098  Third time visit to this hotel. Rooms renovate...            1

# %%
#list to hold percentages parallel to sub1 iteration
percent_list = []
for i in range(len(testsub)):
    # get current rows index
    current_index= testsub['index'].iloc[i]
    # get text count of part
    char_count = len(testsub['part'].iloc[i])
    # find row in reviews
    reviews_row = reviews[reviews['Index'] == current_index]
    # get character count of reviews text
    rev_char_count = len(reviews_row['reviews.text'].iloc[0])
    
    # divide to get percentage
    percentage = char_count / rev_char_count
    # add to list
    percent_list.append(percentage)
    
    print(f"character count: {char_count}")
    print(rev_char_count)
    print('------------------')

percent_list
# Out:
# character count: 687
# 687
# ------------------
# character count: 200
# 501
# ------------------
# [1.0, 0.3992015968063872]

# %%
reviews.columns
# Out:
# Index(['Index', 'reviews.ratings', 'reviews.text'], dtype='object')

# %%
result = reviews[reviews['Index'] == 8884]


len(result['reviews.text'].iloc[0])
# Out:
# 687

# %%
result
# Out:
#      Index reviews.ratings                                       reviews.text
# 228   8884        positive  Excellent hotel in a great location. Close eno...

# %%
687 / 50
# Out:
# 13.74

# %%
testsub.columns
# Out:
# Index(['index', 'part', 'Annotations'], dtype='object')

# %%
sub1parts=[sub1['part'].iloc[i] for i in range(len(sub1))]

# %%
sub1parts[4990:]
# Out:
# ['The overall hotel was clean. The staff was friendly. The breakfast was good. About a 7 minute drive to the Dallas Convention Center. Would recommend this hotel as a good place to stay. We will stay here again if in the area.Greetings Thank you very much for taking the time to review our property.Your input, and the feedback from all of our guests is vitally important to us and we always want guest expectations to be met upon arrival.We hop',
#  'Beautiful modern king city view suite. A few quirks like 12th floor check in a',
#  'The most important thing in Arizona is a SUPER LARGE AIR CONDITIONER. This American, Locally owned and operated inn, has everything you could want without paying the extra fee a franchised property would char',
#  'if you stay in this hotel dont accept room 107 as this room is opposite the ice machine and washing machine and drinks vending machines people leaving the door open all night the lady who works in the hotel coming for ice at 5.20am every...More',
#  'The JW Marriott was very nice and convenient to shopping at Lenox mall. We had a nice stay here. Lots of parking and convenient to restaurants in downtown Buckhead. Just be aware that you wi',
#  'Please avoid this hotel. After Hampton Inn lost our reservation, Lilana was the rudest customer service employee I have encountered in a very long time. I frequently stay at Hampton Inn and was shocked at the treatment I received. The smallest amount of courtesy would have solved my problem without incident. I have never posted a review, but wanted everyone to be spared a similar experience.Thank you for your review. Please accept my sincere apologies for the poor level of service that you received this is not the Hampton norm as our goal is Satisfaction Guaranteed. I have addressed these issues with our staff, and hope that the next time you are in the area you will come stay with us again and experience an improved level of customer service. Hotel General Manager',
#  'Cannot recommend this place enough. Great ',
#  "Annual sibling reunion (3 siblings plus spouses) in San Antonio at the Hotel Emma. I'd seen an article about the Emma years ago and added it to my MustGoThere List. Intriguing building mak",
#  "Everyone, from Rebecca at check-in, Deborah at check-out, the ladies during breakfast (I didn't get their names) and Carlos from maintenance were more than accommodating, super friendly and pleasant. They made sure we got what we needed and the adjoining rooms we needed were provided. The hotel itself was clean, quiet and modern, but the customer service is what made it perfect.Dear Guest Tina M, I would like to thank you for taking time out of your busy schedule to write about your experience during your stay at the Hilton Garden inn Orlando Airport. We know that when traveling our guests have many options to choose from and we value and deeply appreciate your loyalty and support. We are constantly monitoring the performance of our team member to make sure our valuable guests as yourself is welcome with an efficient and pleasant front desk procedure that provides the accommodations and service you expect. We want our guests to be met with a well-trained staff that puts guest comfort and satisfaction before everything else. Your comments have been communicated to all our associates and posted in our bullet",
#  'Ottimo hotel situato in buona posizione a met strada tra le spiaggie e Downtown. Molto piacevole la vista sul porticciolo. Perfetto il parking incluso e la colazione molto ben fornita . Alla reception sono sempre dispo']

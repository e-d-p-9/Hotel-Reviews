# %% [markdown]
# # add percentage column to split hotel sub 1 csv

# %%
import pandas as pd
# Out:
# /var/folders/q6/7cdr_lr528137k1jpb413r7h0000gn/T/ipykernel_12077/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# read in hotel_sub_1
data = pd.read_csv("Hotel_Sub_1.csv", index_col='index')

# %%
data
# Out:
#                                                     part  Annotations
# index
# 8884   Excellent hotel in a great location. Close eno...            0
# 1098   Third time visit to this hotel. Rooms renovate...            1
# 4870   When we fly into Orlando to visit family on th...            1
# 6665   Close to airport but also close to a noisy roa...            1
# 7456   This is a great choice for Love Field area. Re...            1
# ...                                                  ...          ...
# 994    Please avoid this hotel. After Hampton Inn los...            1
# 5354          Cannot recommend this place enough. Great             1
# 3532   Annual sibling reunion (3 siblings plus spouse...            1
# 4915   Everyone, from Rebecca at check-in, Deborah at...            1
# 6647   Ottimo hotel situato in buona posizione a met ...            1
#
# [5000 rows x 2 columns]

# %%
data = data.sort_values(by=['index'])

# %%
data.to_csv('hotelsub1_index_sort.csv')

# %%
# add a num characters column using numbers on mac

# %%
# read in the new dataset with numcharacters column
data = pd.read_csv("/Users/ethan/GitHub_Desktop/Hotel-Reviews/task2/hotel_sub_1_num_chars_col_added(macNumbers).csv", index_col='index')

# %%
data
# Out:
#                                                     part  Annotations  \
# index
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            0
# 11     This is a new Hampton Inn and is well decorate...            1
# ...                                                  ...          ...
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            2
# 9999         Awesome wings (my favorite was garlic parme            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
#
#        Num Characters
# index
# 11                103
# 11                 52
# 11                155
# ...

# %% [markdown]
# 1 get all indexes as a list
#
# sort these indexes based on the character count ascending
#
# example
#
# 100     157
#
# 20      30
#
# 80      120
#
# 40      75
#
# 60      100

# %%
data
# Out:
#                                                     part  Annotations  \
# index
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            0
# 11     This is a new Hampton Inn and is well decorate...            1
# ...                                                  ...          ...
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            2
# 9999         Awesome wings (my favorite was garlic parme            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
#
#        Num Characters
# index
# 11                103
# 11                 52
# 11                155
# ...

# %%
unique_index = data.index.unique()

# %%
# dir(unique_index)

# %%
# unique_index.values

# %%
values = unique_index.values
values[0]
# Out:
# 11

# %% [markdown]
# <hr>/

# %%
# change the value of the article number to something other than index in numbers and retry:

# %%
# read in index sorted hotelsub1 with new title for index column that really means class label
df = pd.read_csv('/Users/ethan/GitHub_Desktop/Hotel-Reviews/task2/hotelsub1_index_sort_class.csv')

# %%
df
# Out:
#       class                                               part  Annotations  \
# 0        11  This is a new Hampton Inn and is well decorate...            1
# 1        11  This is a new Hampton Inn and is well decorate...            1
# 2        11  This is a new Hampton Inn and is well decorate...            1
# 3        11  This is a new Hampton Inn and is well decorate...            0
# 4        11  This is a new Hampton Inn and is well decorate...            1
# ...     ...                                                ...          ...
# 4995   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4996   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4997   9999  Awesome wings (my favorite was garlic parmesan...            2
# 4998   9999        Awesome wings (my favorite was garlic parme            1
# 4999   9999  Awesome wings (my favorite was garlic parmesan...            1
#
#       Num Characters
# 0                103
# ...

# %%
unique_values = df['class'].unique()
unique_values
# Out:
# array([  11,   20,   23,   25,   29,   39,   43,   57,   72,   88,   89,
#          97,  103,  105,  108,  111,  113,  135,  167,  193,  197,  208,
#         216,  241,  256,  261,  266,  267,  281,  287,  294,  300,  301,
#         324,  330,  359,  374,  385,  391,  392,  394,  403,  406,  407,
#         423,  427,  431,  439,  492,  510,  533,  543,  546,  548,  552,
#         556,  577,  581,  591,  606,  608,  615,  631,  632,  637,  639,
#         649,  654,  667,  686,  694,  696,  705,  708,  728,  729,  730,
#         742,  752,  772,  780,  787,  788,  795,  813,  823,  831,  843,
#         846,  849,  855,  861,  872,  875,  878,  879,  881,  904,  929,
#         950,  953,  955,  964,  983,  994, 1008, 1040, 1054, 1060, 1066,
#        1076, 1098, 1103, 1136, 1145, 1149, 1154, 1161, 1166, 1178, 1189,
#        1191, 1202, 1203, 1204, 1215, 1220, 1224, 1225, 1227, 1233, 1236,
#        1241, 1267, 1276, 1280, 1293, 1296, 1299, 1304, 1311, 1334, 1335,
# ...

# %%
len(unique_values)
# Out:
# 1000

# %%
unique_values[0]
# Out:
# 11

# %%
df.loc[df['class'] == unique_values[0]]
# Out:
#    class                                               part  Annotations  \
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
# 4     11  This is a new Hampton Inn and is well decorate...            1
#
#    Num Characters
# 0             103
# 1              52
# 2             155
# 3             261
# 4             207

# %%
# cool so we can get each part with this and then sort ?
df.loc[df['class'] == unique_values[0]].sort_values(by='Num Characters')
# Out:
#    class                                               part  Annotations  \
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 4     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
#
#    Num Characters
# 1              52
# 0             103
# 2             155
# 4             207
# 3             261

# %%
# now iterate through these rows and append 20, 40, 60, 80, 100 to each
# so go through each row and add 20 40 60 80 100

start_num = 20
incrementer = 20

for i in range(5):
    print(start_num)
    start_num += incrementer


print("there are the labels for the class sorted by num characters")
# Out:
# 20
# 40
# 60
# 80
# 100
# there are the labels for the class sorted by num characters

# %%
test = df.loc[df['class'] == unique_values[0]].sort_values(by='Num Characters')
test
# Out:
#    class                                               part  Annotations  \
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 4     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
#
#    Num Characters
# 1              52
# 0             103
# 2             155
# 4             207
# 3             261

# %%
print("test is the first class sorted by number of characers add the percentage labels to it")
# Out:
# test is the first class sorted by number of characers add the percentage labels to it

# %%
print("lets actually create a new dataframe that is the entire dataframe sorted by num characters by the first class example so 11")
# Out:
# lets actually create a new dataframe that is the entire dataframe sorted by num characters by the first class example so 11

# %%
df
# Out:
#       class                                               part  Annotations  \
# 0        11  This is a new Hampton Inn and is well decorate...            1
# 1        11  This is a new Hampton Inn and is well decorate...            1
# 2        11  This is a new Hampton Inn and is well decorate...            1
# 3        11  This is a new Hampton Inn and is well decorate...            0
# 4        11  This is a new Hampton Inn and is well decorate...            1
# ...     ...                                                ...          ...
# 4995   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4996   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4997   9999  Awesome wings (my favorite was garlic parmesan...            2
# 4998   9999        Awesome wings (my favorite was garlic parme            1
# 4999   9999  Awesome wings (my favorite was garlic parmesan...            1
#
#       Num Characters
# 0                103
# ...

# %%
testdf = df

# %%
testdf.loc[testdf['class'] == unique_values[0]] = testdf.loc[testdf['class'] == unique_values[0]].sort_values(by="Num Characters")

# %%
testdf
# Out:
#       class                                               part  Annotations  \
# 0        11  This is a new Hampton Inn and is well decorate...            1
# 1        11  This is a new Hampton Inn and is well decorate...            1
# 2        11  This is a new Hampton Inn and is well decorate...            1
# 3        11  This is a new Hampton Inn and is well decorate...            0
# 4        11  This is a new Hampton Inn and is well decorate...            1
# ...     ...                                                ...          ...
# 4995   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4996   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4997   9999  Awesome wings (my favorite was garlic parmesan...            2
# 4998   9999        Awesome wings (my favorite was garlic parme            1
# 4999   9999  Awesome wings (my favorite was garlic parmesan...            1
#
#       Num Characters
# 0                103
# ...

# %%
print("that didn't work just populate a new dataframe with the sorted values")
# Out:
# that didn't work just populate a new dataframe with the sorted values

# %%
print("try again with just setting it equal")
# Out:
# try again with just setting it equal

# %%
testing = testdf.loc[testdf['class'] == unique_values[0]].sort_values(by="Num Characters")

# %%
testing
# Out:
#    class                                               part  Annotations  \
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 4     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
#
#    Num Characters
# 1              52
# 0             103
# 2             155
# 4             207
# 3             261

# %%
# create empty dataframe and append our sorted results
sorted_num_char_df = pd.DataFrame(columns=['class','part', 'Annotations', 'Num Characters'])
sorted_num_char_df = pd.concat([sorted_num_char_df, testing])
sorted_num_char_df = pd.concat([sorted_num_char_df, testing])

sorted_num_char_df
# Out:
#   class                                               part Annotations  \
# 1    11  This is a new Hampton Inn and is well decorate...           1
# 0    11  This is a new Hampton Inn and is well decorate...           1
# 2    11  This is a new Hampton Inn and is well decorate...           1
# 4    11  This is a new Hampton Inn and is well decorate...           1
# 3    11  This is a new Hampton Inn and is well decorate...           0
# 1    11  This is a new Hampton Inn and is well decorate...           1
# 0    11  This is a new Hampton Inn and is well decorate...           1
# 2    11  This is a new Hampton Inn and is well decorate...           1
# 4    11  This is a new Hampton Inn and is well decorate...           1
# 3    11  This is a new Hampton Inn and is well decorate...           0
#
#   Num Characters
# 1             52
# 0            103
# 2            155
# 4            207
# 3            261
# 1             52
# 0            103
# 2            155
# 4            207
# ...

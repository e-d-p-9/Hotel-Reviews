# %% [markdown]
# # add percentage column to split hotel sub 1 csv

# %%
import pandas as pd
# Out:
# /var/folders/q6/7cdr_lr528137k1jpb413r7h0000gn/T/ipykernel_12077/4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# read in hotel_sub_1
data = pd.read_csv("Hotel_Sub_1.csv", index_col='index')

# %%
data
# Out:
#                                                     part  Annotations
# index
# 8884   Excellent hotel in a great location. Close eno...            0
# 1098   Third time visit to this hotel. Rooms renovate...            1
# 4870   When we fly into Orlando to visit family on th...            1
# 6665   Close to airport but also close to a noisy roa...            1
# 7456   This is a great choice for Love Field area. Re...            1
# ...                                                  ...          ...
# 994    Please avoid this hotel. After Hampton Inn los...            1
# 5354          Cannot recommend this place enough. Great             1
# 3532   Annual sibling reunion (3 siblings plus spouse...            1
# 4915   Everyone, from Rebecca at check-in, Deborah at...            1
# 6647   Ottimo hotel situato in buona posizione a met ...            1
#
# [5000 rows x 2 columns]

# %%
data = data.sort_values(by=['index'])

# %%
data.to_csv('hotelsub1_index_sort.csv')

# %%
# add a num characters column using numbers on mac

# %%
# read in the new dataset with numcharacters column
data = pd.read_csv("/Users/ethan/GitHub_Desktop/Hotel-Reviews/task2/hotel_sub_1_num_chars_col_added(macNumbers).csv", index_col='index')

# %%
data
# Out:
#                                                     part  Annotations  \
# index
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            0
# 11     This is a new Hampton Inn and is well decorate...            1
# ...                                                  ...          ...
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            2
# 9999         Awesome wings (my favorite was garlic parme            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
#
#        Num Characters
# index
# 11                103
# 11                 52
# 11                155
# 11                261
# 11                207
# ...               ...
# 9999              181
# 9999               73
# 9999              144
# 9999               37
# 9999              108
#
# [5000 rows x 3 columns]

# %% [markdown]
# 1 get all indexes as a list
#
# sort these indexes based on the character count ascending
#
# example
#
# 100     157
#
# 20      30
#
# 80      120
#
# 40      75
#
# 60      100

# %%
data
# Out:
#                                                     part  Annotations  \
# index
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            0
# 11     This is a new Hampton Inn and is well decorate...            1
# ...                                                  ...          ...
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            2
# 9999         Awesome wings (my favorite was garlic parme            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
#
#        Num Characters
# index
# 11                103
# 11                 52
# 11                155
# 11                261
# 11                207
# ...               ...
# 9999              181
# 9999               73
# 9999              144
# 9999               37
# 9999              108
#
# [5000 rows x 3 columns]

# %%
unique_index = data.index.unique()

# %%
# dir(unique_index)

# %%
# unique_index.values

# %%
values = unique_index.values
values[0]
# Out:
# 11

# %%
data
# Out:
#                                                     part  Annotations  \
# index
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            1
# 11     This is a new Hampton Inn and is well decorate...            0
# 11     This is a new Hampton Inn and is well decorate...            1
# ...                                                  ...          ...
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
# 9999   Awesome wings (my favorite was garlic parmesan...            2
# 9999         Awesome wings (my favorite was garlic parme            1
# 9999   Awesome wings (my favorite was garlic parmesan...            1
#
#        Num Characters
# index
# 11                103
# 11                 52
# 11                155
# 11                261
# 11                207
# ...               ...
# 9999              181
# 9999               73
# 9999              144
# 9999               37
# 9999              108
#
# [5000 rows x 3 columns]

# %%
data.loc['index'] == 11
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:161, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 data.loc['index'] == 11
#
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
#    1381     # GH#5567 this will fail if the label is not present in the axis.
# -> 1382     return self.obj.xs(label, axis=axis)
#
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/generic.py:4295, in NDFrame.xs(self, key, axis, level, drop_level)
#    4293             new_index = index[loc]
#    4294 else:
# -> 4295     loc = index.get_loc(key)
#    4297     if isinstance(loc, np.ndarray):
#    4298         if loc.dtype == np.bool_:
#
# File ~/venvs/session/lib/python3.9/site-packages/pandas/core/indexes/base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'index'

# %%
data.loc[data['']]

# %%
# retry without specifying index so we can see just the article assosiations
# read in the new dataset with numcharacters column
data = pd.read_csv("/Users/ethan/GitHub_Desktop/Hotel-Reviews/task2/hotel_sub_1_num_chars_col_added(macNumbers).csv")

# %%
data
# Out:
#       index                                               part  Annotations  \
# 0        11  This is a new Hampton Inn and is well decorate...            1
# 1        11  This is a new Hampton Inn and is well decorate...            1
# 2        11  This is a new Hampton Inn and is well decorate...            1
# 3        11  This is a new Hampton Inn and is well decorate...            0
# 4        11  This is a new Hampton Inn and is well decorate...            1
# ...     ...                                                ...          ...
# 4995   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4996   9999  Awesome wings (my favorite was garlic parmesan...            1
# 4997   9999  Awesome wings (my favorite was garlic parmesan...            2
# 4998   9999        Awesome wings (my favorite was garlic parme            1
# 4999   9999  Awesome wings (my favorite was garlic parmesan...            1
#
#       Num Characters
# 0                103
# 1                 52
# 2                155
# 3                261
# 4                207
# ...              ...
# 4995             181
# 4996              73
# 4997             144
# 4998              37
# 4999             108
#
# [5000 rows x 4 columns]

# %%
df = data

# %%
df.loc[df['index'] == values[0]]
# Out:
#    index                                               part  Annotations  \
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
# 4     11  This is a new Hampton Inn and is well decorate...            1
#
#    Num Characters
# 0             103
# 1              52
# 2             155
# 3             261
# 4             207

# %%
# cool so we can get each part with this and then sort ?

# %%
test_frame = df.loc[df['index'] == values[0]]

# %%
test_frame
# Out:
#    index                                               part  Annotations  \
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
# 4     11  This is a new Hampton Inn and is well decorate...            1
#
#    Num Characters
# 0             103
# 1              52
# 2             155
# 3             261
# 4             207

# %%
test_frame.sort_values(by='Num Characters')
# Out:
#    index                                               part  Annotations  \
# 1     11  This is a new Hampton Inn and is well decorate...            1
# 0     11  This is a new Hampton Inn and is well decorate...            1
# 2     11  This is a new Hampton Inn and is well decorate...            1
# 4     11  This is a new Hampton Inn and is well decorate...            1
# 3     11  This is a new Hampton Inn and is well decorate...            0
#
#    Num Characters
# 1              52
# 0             103
# 2             155
# 4             207
# 3             261

# %%
# now iterate through these rows and append 20, 40, 60, 80, 100 to each
